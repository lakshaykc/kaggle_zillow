# %% [markdown]
# # Data Analysis Notebook

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns
color = sns.color_palette()
from itertools import compress
from sklearn.ensemble import ExtraTreesRegressor
from scipy.stats import norm

# %matplotlib inline

pd.options.mode.chained_assignment = None
pd.options.display.max_columns = 999

# %% [markdown]
# # Section 1: Setting up the data

# %% [markdown]
# Loading the data from csv files. Data has been stored as dataframes in pickle and just needs to loaded

# %%
#train_df = pd.read_csv("../data/input/train_2016_v2.csv", parse_dates=["transactiondate"])
#train_df.shape
# Out:
# (90275, 3)

# %%
#prop_df = pd.read_csv("../data/input/properties_2016.csv")
#prop_df.shape
# Out:
# C:\Anaconda2\lib\site-packages\IPython\core\interactiveshell.py:2902: DtypeWarning: Columns (22,32,34,49,55) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# (2985217, 58)

# %%
# Pickle the data frames
#train_df.to_pickle("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\train_df.pkl")
#prop_df.to_pickle("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\prop_df.pkl")

# %%
# Read dataframes from pickle
train_df = pd.read_pickle("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\train_df.pkl")
prop_df = pd.read_pickle("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\prop_df.pkl")

# %%
train_df = train_df.merge(prop_df,on='parcelid',how='left')
train_df.head()
# Out:
#    parcelid  logerror transactiondate  airconditioningtypeid  \
# 0  11016594    0.0276      2016-01-01                    1.0
# 1  14366692   -0.1684      2016-01-01                    NaN
# 2  12098116   -0.0040      2016-01-01                    1.0
# 3  12643413    0.0218      2016-01-02                    1.0
# 4  14432541   -0.0050      2016-01-02                    NaN
#
#    architecturalstyletypeid  basementsqft  bathroomcnt  bedroomcnt  \
# 0                       NaN           NaN          2.0         3.0
# 1                       NaN           NaN          3.5         4.0
# 2                       NaN           NaN          3.0         2.0
# 3                       NaN           NaN          2.0         2.0
# 4                       NaN           NaN          2.5         4.0
#
#    buildingclasstypeid  buildingqualitytypeid  calculatedbathnbr  decktypeid  \
# 0                  NaN                    4.0                2.0         NaN
# 1                  NaN                    NaN                3.5         NaN
# 2                  NaN                    4.0                3.0         NaN
# 3                  NaN                    4.0                2.0         NaN
# 4                  NaN                    NaN                2.5         NaN
#
#    finishedfloor1squarefeet  calculatedfinishedsquarefeet  \
# 0                       NaN                        1684.0
# 1                       NaN                        2263.0
# 2                       NaN                        2217.0
# 3                       NaN                         839.0
# 4                       NaN                        2283.0
#
#    finishedsquarefeet12  finishedsquarefeet13  finishedsquarefeet15  \
# 0                1684.0                   NaN                   NaN
# 1                2263.0                   NaN                   NaN
# 2                2217.0                   NaN                   NaN
# 3                 839.0                   NaN                   NaN
# 4                2283.0                   NaN                   NaN
#
#    finishedsquarefeet50  finishedsquarefeet6    fips  fireplacecnt  \
# 0                   NaN                  NaN  6037.0           NaN
# 1                   NaN                  NaN  6059.0           NaN
# 2                   NaN                  NaN  6037.0           NaN
# 3                   NaN                  NaN  6037.0           NaN
# 4                   NaN                  NaN  6059.0           NaN
#
#    fullbathcnt  garagecarcnt  garagetotalsqft hashottuborspa  \
# 0          2.0           NaN              NaN            NaN
# 1          3.0           2.0            468.0            NaN
# 2          3.0           NaN              NaN            NaN
# 3          2.0           NaN              NaN            NaN
# 4          2.0           2.0            598.0            NaN
#
#    heatingorsystemtypeid    latitude    longitude  lotsizesquarefeet  poolcnt  \
# 0                    2.0  34280990.0 -118488536.0             7528.0      NaN
# 1                    NaN  33668120.0 -117677556.0             3643.0      NaN
# 2                    2.0  34136312.0 -118175032.0            11423.0      NaN
# 3                    2.0  33755800.0 -118309000.0            70859.0      NaN
# 4                    NaN  33485643.0 -117700234.0             6000.0      1.0
#
#    poolsizesum  pooltypeid10  pooltypeid2  pooltypeid7  \
# 0          NaN           NaN          NaN          NaN
# 1          NaN           NaN          NaN          NaN
# 2          NaN           NaN          NaN          NaN
# 3          NaN           NaN          NaN          NaN
# 4          NaN           NaN          NaN          1.0
#
#   propertycountylandusecode  propertylandusetypeid propertyzoningdesc  \
# 0                      0100                  261.0               LARS
# 1                         1                  261.0                NaN
# 2                      0100                  261.0               PSR6
# 3                      010C                  266.0               LAR3
# 4                       122                  261.0                NaN
#
#    rawcensustractandblock  regionidcity  regionidcounty  regionidneighborhood  \
# 0            6.037107e+07       12447.0          3101.0               31817.0
# 1            6.059052e+07       32380.0          1286.0                   NaN
# 2            6.037464e+07       47019.0          3101.0              275411.0
# 3            6.037296e+07       12447.0          3101.0               54300.0
# 4            6.059042e+07       17686.0          1286.0                   NaN
#
#    regionidzip  roomcnt  storytypeid  threequarterbathnbr  \
# 0      96370.0      0.0          NaN                  NaN
# 1      96962.0      0.0          NaN                  1.0
# 2      96293.0      0.0          NaN                  NaN
# 3      96222.0      0.0          NaN                  NaN
# 4      96961.0      8.0          NaN                  1.0
#
#    typeconstructiontypeid  unitcnt  yardbuildingsqft17  yardbuildingsqft26  \
# 0                     NaN      1.0                 NaN                 NaN
# 1                     NaN      NaN                 NaN                 NaN
# 2                     NaN      1.0                 NaN                 NaN
# 3                     NaN      1.0                 NaN                 NaN
# 4                     NaN      NaN                 NaN                 NaN
#
#    yearbuilt  numberofstories fireplaceflag  structuretaxvaluedollarcnt  \
# 0     1959.0              NaN           NaN                    122754.0
# 1     2014.0              NaN           NaN                    346458.0
# 2     1940.0              NaN           NaN                     61994.0
# 3     1987.0              NaN           NaN                    171518.0
# 4     1981.0              2.0           NaN                    169574.0
#
#    taxvaluedollarcnt  assessmentyear  landtaxvaluedollarcnt  taxamount  \
# 0           360170.0          2015.0               237416.0    6735.88
# 1           585529.0          2015.0               239071.0   10153.02
# 2           119906.0          2015.0                57912.0   11484.48
# 3           244880.0          2015.0                73362.0    3048.74
# 4           434551.0          2015.0               264977.0    5488.96
#
#   taxdelinquencyflag  taxdelinquencyyear  censustractandblock
# 0                NaN                 NaN         6.037107e+13
# 1                NaN                 NaN                  NaN
# 2                NaN                 NaN         6.037464e+13
# 3                NaN                 NaN         6.037296e+13
# 4                NaN                 NaN         6.059042e+13

# %%
train_df.to_csv("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\train_df_1.csv")

# %% [markdown]
# # Section 2: Missing Data

# %% [markdown]
# Understand the handling of missing data

# %%
# Missing features
missing_df = train_df.isnull().sum(axis=0).reset_index()
missing_df.columns = ['column_name', 'missing_count']
missing_df = missing_df.ix[missing_df['missing_count']>0]
missing_df = missing_df.sort_values(by='missing_count')

print missing_df['column_name'].count()

ind = np.arange(missing_df.shape[0])
width = 0.9
fig, ax = plt.subplots(figsize=(12,18))
rects = ax.barh(ind, missing_df.missing_count.values, color='blue')
ax.set_yticks(ind)
ax.set_yticklabels(missing_df.column_name.values, rotation='horizontal')
ax.set_xlabel("Count of missing values")
ax.set_title("Number of missing values in each column")
plt.show()
# Out:
# 47
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:4: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %% [markdown]
# 29 features have more than 50% of the data missing. Refer to the handling of missing data sheet for details to fill the values

# %%
train_df2 = train_df.fillna(train_df.median(),inplace=True)

# %%
train_df2.to_csv("C:\\Users\\lakshay\\Documents\\zes\\zestims\\data\\input\\train_df_2.csv")

# %%
# Zip code distribution - first look
# NOte that zip codes are masked and do not denote the actual values

df_x = train_df2[train_df2["regionidzip"].values<100000]
plt.figure(figsize=(12,8))
g = sns.distplot(df_x.regionidzip.values,fit=norm, bins=100, kde=False )
#g.set(xlim=(90000,110000))
plt.xlabel('Zip', fontsize=12)
plt.show()

# %% [markdown]
# # Section 3: Feature Importance

# %% [markdown]
# Feature importance results from random forest model. The model was trained on AWS on 16 cores and took about 3 hours. Refer to Lakshay for the details of the model. The results have been imported in this notebook.

# %%
# without transaction month
imp_df = pd.read_csv("C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\impv2.csv")
imp_df = imp_df.sort_values(by=['%IncMSE'])
imp_df

# For definitions of IncMSe and IncNOdePurity refer to the random forest R importance method
# Out:
#                             Name   %IncMSE  IncNodePurity
# 45            yardbuildingsqft26 -0.864914       0.347162
# 3       architecturalstyletypeid -0.680953       0.104424
# 19                  fireplacecnt -0.540144       1.464051
# 44            yardbuildingsqft17 -0.218070       6.718918
# 31                   pooltypeid7  0.000000       0.000000
# 40                   storytypeid  0.000000       0.000000
# 42        typeconstructiontypeid  0.000000       0.000161
# 30                   pooltypeid2  0.000000       0.000000
# 10                    decktypeid  0.000000       0.000000
# 29                  pooltypeid10  0.000000       0.000000
# 7            buildingclasstypeid  0.000000       0.000000
# 50                assessmentyear  0.000000       0.000000
# 27                       poolcnt  0.000000       0.000000
# 28                   poolsizesum  0.143921       0.968270
# 14          finishedsquarefeet13  0.218579       0.071346
# 41           threequarterbathnbr  0.224221       1.035529
# 47               numberofstories  0.451344       3.699505
# 53            taxdelinquencyyear  0.517163      13.226423
# 4                   basementsqft  0.610461       0.541559
# 18                          fips  0.619007       1.741367
# 16          finishedsquarefeet50  0.694672       7.992128
# 2          airconditioningtypeid  0.736246       3.907784
# 15          finishedsquarefeet15  0.787512      20.678644
# 17           finishedsquarefeet6  0.925925       4.089408
# 21                  garagecarcnt  0.978417       6.312276
# 36                regionidcounty  0.996197       1.758131
# 23         heatingorsystemtypeid  1.037977      10.690049
# 20                   fullbathcnt  1.141865      14.467689
# 32     propertycountylandusecode  1.156399      21.095319
# 22               garagetotalsqft  1.177404      16.285542
# 11      finishedfloor1squarefeet  1.190520       8.428331
# 24                      latitude  1.335318     110.329602
# 39                       roomcnt  1.386409      18.973377
# 1                transactiondate  1.426338      90.090512
# 55             transaction_month  1.500307     103.052800
# 8          buildingqualitytypeid  1.642990      19.009009
# 13          finishedsquarefeet12  1.780590      95.042159
# 6                     bedroomcnt  1.949040      39.432335
# 43                       unitcnt  2.007096       5.372386
# 9              calculatedbathnbr  2.089023      22.350017
# 38                   regionidzip  2.103540      75.218952
# 35                  regionidcity  2.135027      42.757503
# 37          regionidneighborhood  2.155939      47.350500
# 5                    bathroomcnt  2.224659      25.443318
# 33         propertylandusetypeid  2.290844      21.188744
# 25                     longitude  2.319476     101.872612
# 54           censustractandblock  2.612184      85.491025
# 26             lotsizesquarefeet  2.668003     109.562432
# 34        rawcensustractandblock  2.905479      83.510063
# 12  calculatedfinishedsquarefeet  2.966560     100.936659
# 0                       parcelid  3.102776     102.245720
# 49             taxvaluedollarcnt  3.609198     110.497107
# 51         landtaxvaluedollarcnt  3.829794     112.281079
# 48    structuretaxvaluedollarcnt  3.977978     124.082049
# 52                     taxamount  5.072355     113.798503
# 46                     yearbuilt  5.553331      87.315011

# %%
#plt.bar(imp_df["Name"].values,imp_df["%IncMSE"].values)
a = imp_df["Name"].values
b = imp_df["%IncMSE"].values
names = np.ndarray.tolist(a)
imp = np.ndarray.tolist(b)
y_pos = np.arange(len(names))
plt.figure(figsize=(16,20))
plt.barh(y_pos,imp, align='center', alpha=0.5)
plt.yticks(y_pos, names);
plt.title("IncMSE")

# %%
# with transaction month
imp_df2 = imp_df.sort_values(by=['IncNodePurity'])
a2 = imp_df2["Name"].values
b2 = imp_df2["IncNodePurity"].values
names = np.ndarray.tolist(a2)
imp = np.ndarray.tolist(b2)
y_pos = np.arange(len(names))
plt.figure(figsize=(16,20))
plt.barh(y_pos,imp, align='center', alpha=0.5)
plt.yticks(y_pos, names);
plt.title("IncNodePurity")

# %%
imp_df_nrmlzd = imp_df.copy()
imp_df_nrmlzd["%IncMSE"]= imp_df["%IncMSE"]/imp_df["%IncMSE"].max()
imp_df_nrmlzd["IncNodePurity"]= imp_df["IncNodePurity"]/imp_df["IncNodePurity"].max()
imp_df_nrmlzd["avg"] = (imp_df_nrmlzd["%IncMSE"] + imp_df_nrmlzd["IncNodePurity"])
imp_df_nrmlzd.sort_values(by=["avg"])
# Out:
#                             Name   %IncMSE  IncNodePurity       avg
# 45            yardbuildingsqft26 -0.155747       0.002798 -0.152949
# 3       architecturalstyletypeid -0.122621       0.000842 -0.121779
# 19                  fireplacecnt -0.097265       0.011799 -0.085466
# 31                   pooltypeid7  0.000000       0.000000  0.000000
# 40                   storytypeid  0.000000       0.000000  0.000000
# 30                   pooltypeid2  0.000000       0.000000  0.000000
# 10                    decktypeid  0.000000       0.000000  0.000000
# 29                  pooltypeid10  0.000000       0.000000  0.000000
# 7            buildingclasstypeid  0.000000       0.000000  0.000000
# 50                assessmentyear  0.000000       0.000000  0.000000
# 27                       poolcnt  0.000000       0.000000  0.000000
# 42        typeconstructiontypeid  0.000000       0.000001  0.000001
# 44            yardbuildingsqft17 -0.039268       0.054149  0.014881
# 28                   poolsizesum  0.025916       0.007803  0.033720
# 14          finishedsquarefeet13  0.039360       0.000575  0.039935
# 41           threequarterbathnbr  0.040376       0.008346  0.048721
# 47               numberofstories  0.081274       0.029815  0.111089
# 4                   basementsqft  0.109927       0.004365  0.114292
# 18                          fips  0.111466       0.014034  0.125500
# 2          airconditioningtypeid  0.132577       0.031494  0.164071
# 16          finishedsquarefeet50  0.125091       0.064410  0.189501
# 36                regionidcounty  0.179387       0.014169  0.193556
# 17           finishedsquarefeet6  0.166733       0.032957  0.199691
# 53            taxdelinquencyyear  0.093127       0.106594  0.199721
# 21                  garagecarcnt  0.176186       0.050872  0.227057
# 23         heatingorsystemtypeid  0.186911       0.086153  0.273064
# 11      finishedfloor1squarefeet  0.214379       0.067925  0.282305
# 15          finishedsquarefeet15  0.141809       0.166653  0.308462
# 20                   fullbathcnt  0.205618       0.116598  0.322216
# 22               garagetotalsqft  0.212018       0.131248  0.343266
# 32     propertycountylandusecode  0.208235       0.170011  0.378246
# 39                       roomcnt  0.249654       0.152910  0.402564
# 43                       unitcnt  0.361422       0.043297  0.404719
# 8          buildingqualitytypeid  0.295857       0.153197  0.449054
# 9              calculatedbathnbr  0.376175       0.180123  0.556298
# 33         propertylandusetypeid  0.412517       0.170764  0.583281
# 5                    bathroomcnt  0.400599       0.205052  0.605651
# 6                     bedroomcnt  0.350968       0.317792  0.668760
# 35                  regionidcity  0.384459       0.344591  0.729049
# 37          regionidneighborhood  0.388224       0.381606  0.769831
# 1                transactiondate  0.256844       0.726056  0.982900
# 38                   regionidzip  0.378789       0.606203  0.984992
# 13          finishedsquarefeet12  0.320635       0.765962  1.086597
# 55             transaction_month  0.270163       0.830521  1.100685
# 24                      latitude  0.240454       0.889167  1.129620
# 54           censustractandblock  0.470382       0.688988  1.159369
# 34        rawcensustractandblock  0.523196       0.673023  1.196219
# 25                     longitude  0.417673       0.821010  1.238683
# 12  calculatedfinishedsquarefeet  0.534195       0.813467  1.347662
# 26             lotsizesquarefeet  0.480433       0.882984  1.363417
# 0                       parcelid  0.558723       0.824017  1.382740
# 49             taxvaluedollarcnt  0.649916       0.890516  1.540432
# 51         landtaxvaluedollarcnt  0.689639       0.904894  1.594533
# 46                     yearbuilt  1.000000       0.703688  1.703688
# 48    structuretaxvaluedollarcnt  0.716323       1.000000  1.716323
# 52                     taxamount  0.913390       0.917123  1.830513

# %%
# Scatter of two importance metrics
x = imp_df_nrmlzd["%IncMSE"].values
y = imp_df_nrmlzd["IncNodePurity"].values
ann = imp_df_nrmlzd["Name"].values
plt.figure(figsize=(10,10))
fig,ax = plt.subplots(figsize=(20,20))
ax.scatter(x,y)
ax.set_xlabel("IncMSE")
ax.set_ylabel("IncNodePurity")
plt.title('Feature Importance on both metrics %IncMSE and %IncNodePurity')
for i,txt in enumerate(ann):
    ax.annotate(txt,(x[i],y[i]))

# %% [markdown]
# The figure above plots the feature importance with respect to IncMSe and IncNodePurity. Higher the metric more, important it is.
#
# This analysis also includes the importance of transaction month

# %%
imp_df_nrmlzd.to_csv("C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\imp_plot.csv")

# %%
train_df_4 = pd.DataFrame.from_csv("C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\train_df_4.csv")

# %%
# Seasonality effects
a = train_df_4.groupby(["transaction_month"]).count()
b1 = a["parcelid"].values
b2 = np.linspace(1,12,12)
plt.figure(figsize=(10,5))
plt.plot(b2,b1,b2,b1,"ro")
plt.xlabel("Month")
plt.ylabel("Num of Transactions")
plt.title("Seasonality")
plt.axvspan(10,12,alpha=0.3,color='red')

# %% [markdown]
# # Section 4: Handling Missing Data

# %% [markdown]
# # section 4.1: Region City ID  - regionidcity

# %%
# region_city_id grouping
x_tmp = train_df.groupby(["regionidcity"]).count()
x_tmp['parcelid'].plot(kind='barh',figsize=(10,20))

# %%
# Prep data for SVM classification
train_df_region = train_df[['regionidcity','longitude','latitude']]
missing_region_id = train_df_region.isnull().sum(axis=0).reset_index()
tdf_region_no_null = train_df_region.dropna()
tdf_region_all_null = train_df_region[~train_df_region.isin(tdf_region_no_null).all(1)]

# %%
# Training SVM model

from sklearn import svm

data_tmp = tdf_region_no_null.as_matrix()
y_ids = data_tmp[:,0]
#creating labels from region ids
region_ids = np.unique(y_ids)
labels = np.linspace(1,len(region_ids),len(region_ids))
y = np.zeros(len(y_ids))
for i in range(len(y_ids)):
    y[i] = labels[list(region_ids).index(y_ids[i])]
    
X = data_tmp[:,1:3]

#clf = svm.SVC()
#clf.fit(X,y)
#pickle.dump(clf,open("region_id_svm.sav",'wb'))

# %%
# Predicting region id for the missing values

import pickle
#pickle.dump(clf,open("region_id_svm.sav",'wb'))
clf = pickle.load(open("C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\region_id_svm.sav",'rb'))
data_to_predict = tdf_region_all_null.as_matrix()
X_test = data_to_predict[:,1:3]

# %%
clf.predict(X_test)
# Useless!
# Out:
# array([ 20.,  20.,  20., ...,  20.,  20.,  20.])

# %% [markdown]
# SVM classification is USELESS!
# Let's plot and see what is going on

# %%
z = y#/177.
cmap = sns.cubehelix_palette(n_colors=177,as_cmap=True)
cm = plt.cm.get_cmap('RdYlBu')

f, ax = plt.subplots(figsize=(15,10))
points = ax.scatter(X[:,0],X[:,1],s=2, c=z, cmap=cm)
ax.scatter(X_test[:,0],X_test[:,1],s=10, c='k', marker='*',label='Missing')
f.colorbar(points)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Missing_region_ids')
plt.legend(loc='upper left',markerscale = 5, prop={'size':20})


# NOTE
# Black points are the missing region ids

# %% [markdown]
# Observation:
#
# SVM classification is pretty much useless as all the data points are being classified as just one region id - 20. Need to look more into the decision boundary of the classification in order to understand the classification.
#
# Another approach is to use mean of all the data points in the the region id and classify based on the minimum distance of the unknown point to the respective means of the regions.

# %%
# Classify region ids using nearest region center method

region_location_mean = np.zeros(shape=(len(region_ids),2))

for idx,val in enumerate(region_ids):
    df_tmp = train_df_region[train_df_region["regionidcity"]==val]
    inp_location = df_tmp.as_matrix()[:,1:3]
    region_mean_tmp = inp_location.mean(axis=0)
    region_location_mean[idx,:] = region_mean_tmp
    
tdf_region_null_filled = tdf_region_all_null.copy()

def classify_region(x,region_location_mean=region_location_mean,region_ids=region_ids):
    
    dist = np.zeros(len(region_ids))
    for i in range(region_location_mean.shape[0]):
        dist[i] = np.sqrt(np.sum(np.square(x-region_location_mean[i,:])))
    
    return  region_ids[np.argmin(dist)]   
    

for j in list(tdf_region_null_filled.index.values):
    x = np.array([tdf_region_null_filled.ix[j]["longitude"],tdf_region_null_filled.ix[j]["latitude"]])
    tdf_region_null_filled.ix[j]["regionidcity"] = classify_region(x)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:23: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
# Plot lat,long with complete data
import matplotlib.patches as patches

tdf_region_complete = pd.concat([tdf_region_no_null,tdf_region_null_filled])
data_comp = tdf_region_complete.as_matrix()
X2 = data_comp[:,1:3]
y2_ids = data_comp[:,0]

#creating labels from region ids
region_ids = np.unique(y2_ids)
labels = np.linspace(1,len(region_ids),len(region_ids))
y2 = np.zeros(len(y2_ids))
for i in range(len(y2_ids)):
    y2[i] = labels[list(region_ids).index(y2_ids[i])]

z2 = y2
cmap = sns.cubehelix_palette(n_colors=177,as_cmap=True)
cm = plt.cm.get_cmap('RdYlBu')

f, ax = plt.subplots(figsize=(15,10))
points = ax.scatter(X2[:,0],X2[:,1],s=2, c=z2, cmap=cm)
ax.add_patch(patches.Rectangle((-1.1861e8,3.436e7),.0012e8,.012e7,fill=False))
ax.text(-1.1861e8,3.45e7,'Misclassification')
f.colorbar(points)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Filled_region_ids')

# %% [markdown]
# Two regions are misclassified (marked box) as red where it is more probable for them to be blue. This can be manually corrected.

# %%
# Correcting the misclassified region

df = tdf_region_complete
df_2 = df[(df["longitude"]>-1.1861e8) & (df["longitude"]<-1.1850e8) & (df['latitude']>3.436e7) & (df['latitude']<3.45e7)]
df_2.groupby(by='regionidcity').count()
# Out:
#               longitude  latitude
# regionidcity
# 10734.0             157       157
# 54311.0            1615      1615

# %%
corrected_id = 54311.0*np.ones(1772)
tdf_region_complete["regionidcity"][(df["longitude"]>-1.1861e8) & (df["longitude"]<-1.1850e8) & \
                                    (df['latitude']>3.436e7) & (df['latitude']<3.45e7)] = corrected_id

# %%
# Plot with corrected regionidcity
data_comp2 = tdf_region_complete.as_matrix()
X3 = data_comp2[:,1:3]
y3_ids = data_comp2[:,0]

#creating labels from region ids
region_ids = np.unique(y3_ids)
labels = np.linspace(1,len(region_ids),len(region_ids))
y3 = np.zeros(len(y3_ids))
for i in range(len(y3_ids)):
    y3[i] = labels[list(region_ids).index(y3_ids[i])]

z3 = y3
cmap = sns.cubehelix_palette(n_colors=177,as_cmap=True)
cm = plt.cm.get_cmap('RdYlBu')

f, ax = plt.subplots(figsize=(15,10))
points = ax.scatter(X3[:,0],X3[:,1],s=2, c=z3, cmap=cm)
f.colorbar(points)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Corrected_region_ids')

# %% [markdown]
# # section 4.2: Region Zip Id  - regionidzip

# %%
# region_zip_id grouping
x_tmp = train_df.groupby(["regionidzip"]).count()
#x_tmp['parcelid'].plot(kind='barh',figsize=(10,30))
#x_tmp['parcelid']

# %%
# Prep data 
train_df_zip = train_df[['regionidzip','longitude','latitude']]
missing_zip_id = train_df_zip.isnull().sum(axis=0).reset_index()
tdf_zip_no_null = train_df_zip.dropna()
tdf_zip_all_null = train_df_zip[~train_df_zip.isin(tdf_zip_no_null).all(1)]

# %%
data_zip_tmp = tdf_zip_no_null.as_matrix()
y_zip_ids = data_zip_tmp[:,0]
#creating labels from region ids
zip_ids = np.unique(y_zip_ids)
labels = np.linspace(1,len(zip_ids),len(zip_ids))
y_zip = np.zeros(len(y_zip_ids))
for i in range(len(y_zip_ids)):
    y_zip[i] = labels[list(zip_ids).index(y_zip_ids[i])]
    
X_zip = data_zip_tmp[:,1:3]

missing_data = tdf_zip_all_null.as_matrix()
X_zip_missing = missing_data[:,1:3]

z_zip = y_zip
cmap = sns.cubehelix_palette(n_colors=388,as_cmap=True)
cm = plt.cm.get_cmap('RdYlBu')

f, ax = plt.subplots(figsize=(15,10))
points = ax.scatter(X_zip[:,0],X_zip[:,1],s=2, c=z_zip, cmap=cm)
ax.scatter(X_zip_missing[:,0],X_zip_missing[:,1],s=40, c='k', marker='*',label='Missing')
f.colorbar(points)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Missing_zip_ids')
plt.legend(loc='upper left',markerscale = 2, prop={'size':20})

# %%
# Classify zip ids using nearest region center method

zip_location_mean = np.zeros(shape=(len(zip_ids),2))

for idx,val in enumerate(zip_ids):
    df_tmp = train_df_zip[train_df_zip["regionidzip"]==val]
    inp_zip_location = df_tmp.as_matrix()[:,1:3]
    zip_mean_tmp = inp_zip_location.mean(axis=0)
    zip_location_mean[idx,:] = zip_mean_tmp
    
tdf_zip_null_filled = tdf_zip_all_null.copy()

def classify_zip(x,zip_location_mean=zip_location_mean,zip_ids=zip_ids):
    
    dist = np.zeros(len(zip_ids))
    for i in range(zip_location_mean.shape[0]):
        dist[i] = np.sqrt(np.sum(np.square(x-zip_location_mean[i,:])))
    
    return  zip_ids[np.argmin(dist)]   
    

for j in list(tdf_zip_null_filled.index.values):
    x = np.array([tdf_zip_null_filled.ix[j]["longitude"],tdf_zip_null_filled.ix[j]["latitude"]])
    tdf_zip_null_filled.ix[j]["regionidzip"] = classify_zip(x)
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:23: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix

# %%
# Plot lat,long with complete data
import matplotlib.patches as patches

tdf_zip_complete = pd.concat([tdf_zip_no_null,tdf_zip_null_filled])
data_zip_comp = tdf_zip_complete.as_matrix()
X2_zip = data_zip_comp[:,1:3]
y2_zip_ids = data_zip_comp[:,0]

#creating labels from region ids
zip_ids = np.unique(y2_zip_ids)
labels = np.linspace(1,len(zip_ids),len(zip_ids))
y2_zip = np.zeros(len(y2_zip_ids))
for i in range(len(y2_zip_ids)):
    y2_zip[i] = labels[list(zip_ids).index(y2_zip_ids[i])]

z2_zip = y2_zip
cmap = sns.cubehelix_palette(n_colors=388,as_cmap=True)
cm = plt.cm.get_cmap('RdYlBu')

f, ax = plt.subplots(figsize=(15,10))
points = ax.scatter(X2_zip[:,0],X2_zip[:,1],s=2, c=z2_zip, cmap=cm)
f.colorbar(points)
plt.xlabel('longitude')
plt.ylabel('latitude')
plt.title('Filled_zip_ids')

# %%
# Save complete dataframes
tdf_zip_complete.to_pickle('C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\tdf_zip_complete.pkl')
tdf_region_complete.to_pickle('C:\\Users\\lakshay\\Documents\\zes\\zestims\\notebooks\\models\\tdf_region_complete.pkl')

# %% [markdown]
# # section 4.3: Full Bathroom Count - fullbathcnt

# %% [markdown]
# Calculate using bathroomcnt which includes half bathrooms as well

# %%
diff = train_df["bathroomcnt"].values - train_df["fullbathcnt"].values
diff_sorted = np.sort(diff)
null_vals = diff_sorted[np.isnan(diff_sorted)]
diff_no_null = diff_sorted[~np.isnan(diff_sorted)]
x = np.arange(0, len(diff_no_null), 1)
print("Number of NANs in fullbathcnt: %i"%len(null_vals))
# Out:
# Number of NANs in fullbathcnt: 1182

# %%
plt.figure(figsize=(15,5))
plt.plot(x,diff_no_null)
plt.xlabel("Number of parcels")
plt.ylabel("Diff")
plt.title("Difference between full_bath_cnt and total_bath_cnt")
diff_a = diff_no_null[x in diff_no_null[x]>=1.5]
print("Number of values with diff greater than 0.5: %i"%len(diff_a))
# Out:
# Number of values with diff greater than 0.5: 7

# %% [markdown]
# Assumption:
# If the difference between total_bath_cnt and full_bath_cnt is 0.5 then it is highly likely that full_bath_count is floor(total_bath_count). For example, if total_bath_cnt is 2.5, full_bath_cnt should be 2.
#
# It is seen only 7 or 0.007% values in the difference are above 1.5. Hence the above assumption is reasonable given 99.993% values have the difference of 0.5 or less. The missing values for full_bath_cnt can be filled with floor(bathroomcnt)
#
# *total_bath_cnt is same as bathroomcnt

# %%
df_fullbathcnt = train_df[["fullbathcnt","bathroomcnt"]]
df_fullbathcnt_no_null = df_fullbathcnt.dropna()
df_fullbathcnt_all_null = df_fullbathcnt[~df_fullbathcnt.isin(df_fullbathcnt_no_null).all(1)]
df_fullbathcnt_all_null
# Out:
#        fullbathcnt  bathroomcnt
# 126            NaN          0.0
# 174            NaN          0.0
# 231            NaN          0.0
# 293            NaN          0.0
# 299            NaN          0.0
# 303            NaN          0.0
# 313            NaN          0.0
# 382            NaN          0.0
# 387            NaN          0.0
# 727            NaN          0.0
# 734            NaN          0.0
# 858            NaN          0.0
# 913            NaN          0.0
# 934            NaN          0.0
# 950            NaN          0.0
# 1200           NaN          0.0
# 1220           NaN          0.0
# 1222           NaN          0.0
# 1227           NaN          0.0
# 1361           NaN          0.0
# 1408           NaN          0.0
# 1533           NaN          0.0
# 1737           NaN          0.0
# 1764           NaN          0.0
# 1898           NaN          0.0
# 1900           NaN          0.0
# 1904           NaN          0.0
# 1982           NaN          0.0
# 1994           NaN          0.0
# 2129           NaN          0.0
# ...            ...          ...
# 87764          NaN          0.0
# 87833          NaN          0.0
# 87908          NaN          0.0
# 87981          NaN          0.0
# 87987          NaN          0.0
# 88175          NaN          0.0
# 88250          NaN          0.0
# 88398          NaN          0.0
# 88438          NaN          0.0
# 88478          NaN          0.0
# 88655          NaN          0.0
# 88676          NaN          0.0
# 88691          NaN          0.0
# 88745          NaN          0.0
# 88774          NaN          0.0
# 88877          NaN          0.0
# 88937          NaN          0.0
# 88944          NaN          4.5
# 89095          NaN          0.0
# 89105          NaN          0.0
# 89271          NaN          0.0
# 89300          NaN          0.0
# 89372          NaN          0.0
# 89630          NaN          0.0
# 89637          NaN          0.0
# 89742          NaN          0.0
# 89752          NaN          0.0
# 89840          NaN          0.0
# 89895          NaN          0.0
# 89999          NaN          0.0
#
# [1182 rows x 2 columns]

# %%
train_df.ix[126]
# Out:
# C:\Anaconda2\lib\site-packages\ipykernel\__main__.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate_ix
#   if __name__ == '__main__':
# parcelid                                   17188935
# logerror                                     -0.002
# transactiondate                 2016-01-04 00:00:00
# airconditioningtypeid                           NaN
# architecturalstyletypeid                        NaN
# basementsqft                                    NaN
# bathroomcnt                                       0
# bedroomcnt                                        0
# buildingclasstypeid                             NaN
# buildingqualitytypeid                           NaN
# calculatedbathnbr                               NaN
# decktypeid                                      NaN
# finishedfloor1squarefeet                        NaN
# calculatedfinishedsquarefeet                    NaN
# finishedsquarefeet12                            NaN
# finishedsquarefeet13                            NaN
# finishedsquarefeet15                            NaN
# finishedsquarefeet50                            NaN
# finishedsquarefeet6                             NaN
# fips                                           6111
# fireplacecnt                                    NaN
# fullbathcnt                                     NaN
# garagecarcnt                                    NaN
# garagetotalsqft                                 NaN
# hashottuborspa                                  NaN
# heatingorsystemtypeid                           NaN
# latitude                                3.42113e+07
# longitude                              -1.19028e+08
# lotsizesquarefeet                             13581
# poolcnt                                         NaN
# poolsizesum                                     NaN
# pooltypeid10                                    NaN
# pooltypeid2                                     NaN
# pooltypeid7                                     NaN
# propertycountylandusecode                      1111
# propertylandusetypeid                           261
# propertyzoningdesc                              NaN
# rawcensustractandblock                  6.11101e+07
# regionidcity                                  51239
# regionidcounty                                 2061
# regionidneighborhood                            NaN
# regionidzip                                   97091
# roomcnt                                           0
# storytypeid                                     NaN
# threequarterbathnbr                             NaN
# typeconstructiontypeid                          NaN
# unitcnt                                         NaN
# yardbuildingsqft17                              NaN
# yardbuildingsqft26                              NaN
# yearbuilt                                       NaN
# numberofstories                                 NaN
# fireplaceflag                                   NaN
# structuretaxvaluedollarcnt                      NaN
# taxvaluedollarcnt                            204653
# assessmentyear                                 2015
# landtaxvaluedollarcnt                        204653
# taxamount                                    2254.2
# taxdelinquencyflag                              NaN
# taxdelinquencyyear                              NaN
# censustractandblock                             NaN
# Name: 126, dtype: object
